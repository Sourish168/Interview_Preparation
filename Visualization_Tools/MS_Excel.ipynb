# %% [markdown]
# Absolutely. For a **Data Analyst interview**, Advanced Excel is still highly relevant, especially for roles involving reporting, business analysis, MIS, finance, operations, and ad-hoc analysis.
#
# Below are **100 MS Excel interview questions**, arranged from **basic → intermediate → advanced**, with extra emphasis on the areas most likely to be tested in practical interviews.
#
# # 📊 100 Excel Interview Questions — Basic to Advanced
#
# ## 🔹 1. Excel Fundamentals — Questions 1–15
#
# 1. What is Microsoft Excel, and why is it used in data analysis?
# 2. What is the difference between a workbook and a worksheet?
# 3. What are rows, columns, and cells?
# 4. What is a cell reference?
# 5. What is the difference between relative, absolute, and mixed references?
# 6. What is the difference between `.xlsx`, `.xls`, `.csv`, and `.xlsm` files?
# 7. What is the Ribbon in Excel?
# 8. What is the Name Box?
# 9. What is the Formula Bar?
# 10. How do you freeze rows or columns in Excel?
# 11. How do you hide and unhide rows or columns?
# 12. How do you find and remove duplicate records?
# 13. How do you sort data in Excel?
# 14. How do you filter data in Excel?
# 15. What is the difference between sorting and filtering?
#
# ---
#
# # 🔹 2. Basic Formulas & Functions — Questions 16–30
#
# 16. What is the difference between a formula and a function?
# 17. What is the `SUM()` function?
# 18. What is the `AVERAGE()` function?
# 19. What is the `MIN()` function?
# 20. What is the `MAX()` function?
# 21. What is the `COUNT()` function?
# 22. What is the difference between `COUNT()`, `COUNTA()`, `COUNTBLANK()`, and `COUNTIF()`?
# 23. What is the `IF()` function?
# 24. How do you use multiple conditions with `IF()`?
# 25. What are `AND()` and `OR()` functions?
# 26. What is `IFERROR()`?
# 27. How do you calculate percentage change in Excel?
# 28. How do you calculate a running total?
# 29. How do you round numbers using `ROUND()`, `ROUNDUP()`, and `ROUNDDOWN()`?
# 30. What is the difference between `SUMIF()` and `SUMIFS()`?
#
# ---
#
# # 🔹 3. Lookup & Reference Functions — Questions 31–45
#
# 31. What is `VLOOKUP()`?
# 32. What are the limitations of `VLOOKUP()`?
# 33. What is `HLOOKUP()`?
# 34. What is `XLOOKUP()`?
# 35. Why is `XLOOKUP()` generally preferred over `VLOOKUP()`?
# 36. What is the difference between exact match and approximate match?
# 37. What is `INDEX()`?
# 38. What is `MATCH()`?
# 39. How do `INDEX()` and `MATCH()` work together?
# 40. What is the difference between `XLOOKUP()` and `INDEX-MATCH`?
# 41. How do you perform a lookup using multiple criteria?
# 42. How do you perform a two-way lookup?
# 43. How do you return multiple matching values?
# 44. What is `CHOOSE()`?
# 45. What are common reasons a lookup returns `#N/A`?
#
# ---
#
# # 🔹 4. Text Functions — Questions 46–55
#
# 46. What are text functions in Excel?
# 47. What is the difference between `LEFT()`, `RIGHT()`, and `MID()`?
# 48. What does `LEN()` do?
# 49. What does `TRIM()` do?
# 50. What is the difference between `TRIM()` and `CLEAN()`?
# 51. What is `CONCAT()`?
# 52. What is `TEXTJOIN()`?
# 53. What is the difference between `CONCAT()` and `TEXTJOIN()`?
# 54. How do you extract first and last names from a full name?
# 55. How would you extract numbers from a text string?
#
# ---
#
# # 🔹 5. Date & Time Functions — Questions 56–65
#
# 56. How does Excel store dates internally?
# 57. What is the difference between a date and a date-time value?
# 58. What are `TODAY()` and `NOW()`?
# 59. What is `DATEDIF()`?
# 60. How do you calculate someone's age from their date of birth?
# 61. What are `YEAR()`, `MONTH()`, and `DAY()`?
# 62. What are `WEEKDAY()` and `WEEKNUM()`?
# 63. What is `EOMONTH()`?
# 64. What is `EDATE()`?
# 65. How do you calculate the number of working days between two dates?
#
# ---
#
# # 🔹 6. Conditional Aggregation & Dynamic Functions — Questions 66–75
#
# 66. What is `COUNTIF()`?
# 67. What is `COUNTIFS()`?
# 68. What is `AVERAGEIF()`?
# 69. What is `AVERAGEIFS()`?
# 70. What is the difference between `SUMIF()` and `SUMIFS()`?
# 71. What is `FILTER()`?
# 72. What is `SORT()`?
# 73. What is `UNIQUE()`?
# 74. What are dynamic arrays in Excel?
# 75. What is the `LET()` function, and why is it useful?
#
# ---
#
# # 🔹 7. Data Analysis & Visualization — Questions 76–85
#
# 76. What is a Pivot Table?
# 77. Why are Pivot Tables useful for Data Analysts?
# 78. How do you create a Pivot Table?
# 79. What is the difference between a Pivot Table and a normal table?
# 80. What are calculated fields in Pivot Tables?
# 81. What is a Pivot Chart?
# 82. What is a slicer?
# 83. What is a timeline in Excel?
# 84. How do you create a dashboard in Excel?
# 85. Which charts would you use to visualize trends, distributions, comparisons, and relationships?
#
# ---
#
# # 🔹 8. Advanced Excel & Data Cleaning — Questions 86–92
#
# 86. What is Power Query in Excel?
# 87. How is Power Query different from normal Excel formulas?
# 88. How do you import data from multiple CSV files using Power Query?
# 89. What is the difference between **Merge** and **Append** in Power Query?
# 90. What is an Excel Table, and why should you use it?
# 91. What are structured references?
# 92. How would you clean a large messy dataset containing missing values, duplicates, inconsistent formats, and incorrect data types?
#
# ---
#
# # 🔹 9. Advanced Excel — Questions 93–100
#
# 93. What is the difference between `INDEX-MATCH`, `XLOOKUP`, and `VLOOKUP`?
# 94. What are array formulas?
# 95. What are dynamic array formulas?
# 96. What is the difference between a formula, a Pivot Table, and Power Query?
# 97. What is What-If Analysis?
# 98. What are Goal Seek, Data Tables, and Scenario Manager?
# 99. How would you optimize a slow Excel workbook containing hundreds of thousands of rows and complex formulas?
# 100. **Given a raw business dataset, explain how you would clean it, analyze it, create KPIs, build a dashboard, and present actionable insights to management.**
#
# # 💻 20 Practical Excel Interview Tasks
#
# For a Data Analyst interview, these are **more important than simply memorizing definitions**.
#
# Try doing each task yourself in Excel:
#
# 1. Find duplicate customer records and remove them.
# 2. Find customers whose sales exceed ₹1 lakh.
# 3. Calculate total sales by region.
# 4. Calculate average sales by product category.
# 5. Find the top 10 customers by revenue.
# 6. Use `XLOOKUP()` to retrieve customer information.
# 7. Solve the same lookup problem using `INDEX-MATCH`.
# 8. Calculate month-over-month sales growth.
# 9. Calculate year-over-year sales growth.
# 10. Create a running sales total.
# 11. Create a Pivot Table showing sales by region and product.
# 12. Add slicers to the Pivot Table.
# 13. Create a monthly sales trend chart.
# 14. Create a dashboard containing Sales, Profit, Orders, Customers, and Growth KPIs.
# 15. Clean a dataset containing inconsistent names and extra spaces.
# 16. Extract first name, last name, and email domain from text.
# 17. Calculate customer age from date of birth.
# 18. Identify customers who have not purchased in the last 90 days.
# 19. Import and combine multiple CSV files using Power Query.
# 20. Take a raw dataset and produce a complete **analysis → KPI report → dashboard → business recommendations**.
