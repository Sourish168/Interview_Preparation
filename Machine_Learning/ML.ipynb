# %% [markdown]
# ## Basic Machine Learning (1–20)
# #### 1. What is Machine Learning?
# #### 1. What are the different types of Machine Learning?
# #### 1. What is supervised learning?
# #### 1. What is unsupervised learning?
# #### 1. What is semi-supervised learning?
# #### 1. What is reinforcement learning?
# #### 1. What is the difference between AI, Machine Learning, and Deep Learning?
# #### 1. What are features and labels?
# #### 1. What is a dataset?
# #### 1. What is training data?
# #### 1. What is testing data?
# #### 1. What is validation data?
# #### 1. What is a machine learning model?
# #### 1. What is model training?
# #### 1. What is model inference?
# #### 1. What is feature engineering?
# #### 1. What is feature selection?
# #### 1. What is feature extraction?
# #### 1. What are structured and unstructured data?
# #### 1. What are the steps in a typical machine learning pipeline?

# %% [markdown]
# ## Data Preprocessing & Feature Engineering (21–40)
# #### 21. Why is data preprocessing important?
# #### 21. How do you handle missing values?
# #### 21. How do you detect and handle outliers?
# #### 21. Why is feature scaling important?
# #### 21. What is normalization?
# #### 21. What is standardization?
# #### 21. What is one-hot encoding?
# #### 21. What is label encoding?
# #### 21. What is ordinal encoding?
# #### 21. How do you encode high-cardinality categorical variables?
# #### 21. What is data leakage?
# #### 21. How can data leakage be prevented?
# #### 21. What is dimensionality reduction?
# #### 21. What is Principal Component Analysis (PCA)?
# #### 21. What is feature importance?
# #### 21. What is multicollinearity?
# #### 21. How do you detect multicollinearity?
# #### 21. Why should data be shuffled before training?
# #### 21. What is class imbalance?
# #### 21. How do you handle imbalanced datasets?

# %% [markdown]
# ## Supervised Learning Algorithms (41–60)
# #### 41. What is Linear Regression?
# #### 41. What assumptions does Linear Regression make?
# #### 41. What is Logistic Regression?
# #### 41. Why is Logistic Regression called "regression"?
# #### 41. What is a Decision Tree?
# #### 41. How does a Decision Tree choose splits?
# #### 41. What is Gini Impurity?
# #### 41. What is Entropy?
# #### 41. What is Information Gain?
# #### 41. What is a Random Forest?
# #### 41. Why is Random Forest better than a single Decision Tree?
# #### 41. What is Gradient Boosting?
# #### 41. What is AdaBoost?
# #### 41. What is XGBoost?
# #### 41. What is LightGBM?
# #### 41. What is CatBoost?
# #### 41. What is Support Vector Machine (SVM)?
# #### 41. What is the kernel trick?
# #### 41. What is K-Nearest Neighbors (KNN)?
# #### 41. What is Naive Bayes, and what assumptions does it make?

# %% [markdown]
# ## Unsupervised Learning (61–70)
# #### 61. What is clustering?
# #### 61. What is K-Means clustering?
# #### 61. How do you choose the optimal number of clusters?
# #### 61. What is the Elbow Method?
# #### 61. What is the Silhouette Score?
# #### 61. What is Hierarchical Clustering?
# #### 61. What is DBSCAN?
# #### 61. What are association rules?
# #### 61. What is the Apriori algorithm?
# #### 61. What are common applications of unsupervised learning?

# %% [markdown]
# ## Model Evaluation (71–85)
# #### 71. What is overfitting?
# #### 71. What is underfitting?
# #### 71. What is the bias-variance tradeoff?
# #### 71. What is cross-validation?
# #### 71. What is K-Fold Cross Validation?
# #### 71. What is Stratified K-Fold?
# #### 71. What is Leave-One-Out Cross Validation (LOOCV)?
# #### 71. What is hyperparameter tuning?
# #### 71. What is Grid Search?
# #### 71. What is Randomized Search?
# #### 71. What is Bayesian Optimization?
# #### 71. What metrics are used for regression models?
# #### 71. What metrics are used for classification models?
# #### 71. What is ROC-AUC, and when is it useful?
# #### 71. What is Precision-Recall AUC, and when is it preferred?

# %% [markdown]
# ## Advanced Machine Learning (86–100)
# #### 86. What is ensemble learning?
# #### 86. What is bagging?
# #### 86. What is boosting?
# #### 86. What is stacking?
# #### 86. What is blending?
# #### 86. What is transfer learning?
# #### 86. What is online learning?
# #### 86. What is concept drift?
# #### 86. What is active learning?
# #### 86. What is explainable AI (XAI)?
# #### 86. What is SHAP, and how is it used?
# #### 86. What is LIME, and how does it differ from SHAP?
# #### 86. How do you deploy a machine learning model to production?
# #### 86. How do you monitor a machine learning model after deployment?
# #### 86. Describe an end-to-end machine learning project from data collection to deployment.

# %% [markdown]
# ## Practical Coding Questions
# #### 101. Build a complete regression model from a CSV dataset.
# #### 101. Build a binary classification model and evaluate it.
# #### 101. Handle missing values and categorical features in a preprocessing pipeline.
# #### 101. Perform feature scaling and compare model performance.
# #### 101. Train and compare multiple classification algorithms.
# #### 101. Tune model hyperparameters using cross-validation.
# #### 101. Perform feature selection and compare results.
# #### 101. Build a clustering model and evaluate the cluster quality.
# #### 101. Save a trained model and use it to make predictions on new data.
# #### 101. Create an end-to-end machine learning pipeline with preprocessing, training, evaluation, and prediction.
