# %% [markdown]
# 🔹 Basic Machine Learning (1–20)
# What is Machine Learning?
# What are the different types of Machine Learning?
# What is supervised learning?
# What is unsupervised learning?
# What is semi-supervised learning?
# What is reinforcement learning?
# What is the difference between AI, Machine Learning, and Deep Learning?
# What are features and labels?
# What is a dataset?
# What is training data?
# What is testing data?
# What is validation data?
# What is a machine learning model?
# What is model training?
# What is model inference?
# What is feature engineering?
# What is feature selection?
# What is feature extraction?
# What are structured and unstructured data?
# What are the steps in a typical machine learning pipeline?
#
# 🔹 Data Preprocessing & Feature Engineering (21–40)
# Why is data preprocessing important?
# How do you handle missing values?
# How do you detect and handle outliers?
# Why is feature scaling important?
# What is normalization?
# What is standardization?
# What is one-hot encoding?
# What is label encoding?
# What is ordinal encoding?
# How do you encode high-cardinality categorical variables?
# What is data leakage?
# How can data leakage be prevented?
# What is dimensionality reduction?
# What is Principal Component Analysis (PCA)?
# What is feature importance?
# What is multicollinearity?
# How do you detect multicollinearity?
# Why should data be shuffled before training?
# What is class imbalance?
# How do you handle imbalanced datasets?
#
# 🔹 Supervised Learning Algorithms (41–60)
# What is Linear Regression?
# What assumptions does Linear Regression make?
# What is Logistic Regression?
# Why is Logistic Regression called "regression"?
# What is a Decision Tree?
# How does a Decision Tree choose splits?
# What is Gini Impurity?
# What is Entropy?
# What is Information Gain?
# What is a Random Forest?
# Why is Random Forest better than a single Decision Tree?
# What is Gradient Boosting?
# What is AdaBoost?
# What is XGBoost?
# What is LightGBM?
# What is CatBoost?
# What is Support Vector Machine (SVM)?
# What is the kernel trick?
# What is K-Nearest Neighbors (KNN)?
# What is Naive Bayes, and what assumptions does it make?
#
# 🔹 Unsupervised Learning (61–70)
# What is clustering?
# What is K-Means clustering?
# How do you choose the optimal number of clusters?
# What is the Elbow Method?
# What is the Silhouette Score?
# What is Hierarchical Clustering?
# What is DBSCAN?
# What are association rules?
# What is the Apriori algorithm?
# What are common applications of unsupervised learning?
#
# 🔹 Model Evaluation (71–85)
# What is overfitting?
# What is underfitting?
# What is the bias-variance tradeoff?
# What is cross-validation?
# What is K-Fold Cross Validation?
# What is Stratified K-Fold?
# What is Leave-One-Out Cross Validation (LOOCV)?
# What is hyperparameter tuning?
# What is Grid Search?
# What is Randomized Search?
# What is Bayesian Optimization?
# What metrics are used for regression models?
# What metrics are used for classification models?
# What is ROC-AUC, and when is it useful?
# What is Precision-Recall AUC, and when is it preferred?
#
# 🔹 Advanced Machine Learning (86–100)
# What is ensemble learning?
# What is bagging?
# What is boosting?
# What is stacking?
# What is blending?
# What is transfer learning?
# What is online learning?
# What is concept drift?
# What is active learning?
# What is explainable AI (XAI)?
# What is SHAP, and how is it used?
# What is LIME, and how does it differ from SHAP?
# How do you deploy a machine learning model to production?
# How do you monitor a machine learning model after deployment?
# Describe an end-to-end machine learning project from data collection to deployment.
#
# ⭐ Bonus: Practical Coding Questions
#
# These coding tasks are frequently asked in interviews:
#
# Build a complete regression model from a CSV dataset.
# Build a binary classification model and evaluate it.
# Handle missing values and categorical features in a preprocessing pipeline.
# Perform feature scaling and compare model performance.
# Train and compare multiple classification algorithms.
# Tune model hyperparameters using cross-validation.
# Perform feature selection and compare results.
# Build a clustering model and evaluate the cluster quality.
# Save a trained model and use it to make predictions on new data.
# Create an end-to-end machine learning pipeline with preprocessing, training, evaluation, and prediction.
