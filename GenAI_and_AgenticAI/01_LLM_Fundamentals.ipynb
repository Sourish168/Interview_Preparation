# %% [markdown]
# 📚 GenAI + Agentic AI — 10 Notebook Question Sets
# 01 — LLM_Fundamentals.ipynb
# A. Generative AI Fundamentals
# What is Generative AI?
# How is Generative AI different from traditional Machine Learning?
# What is the difference between discriminative and generative models?
# What are the major types of Generative AI models?
# What is an LLM?
# How does an LLM generate text?
# What is the difference between an LLM and a traditional NLP model?
# What are some popular LLMs?
# What are the major components of an LLM?
# What is pre-training?
# What is fine-tuning?
# What is instruction tuning?
# What is alignment in LLMs?
# What is RLHF?
# What is DPO?
# What is supervised fine-tuning (SFT)?
# What is the difference between pre-training and fine-tuning?
# What is an instruction-following model?
# What is a foundation model?
# What are the limitations of LLMs?
# B. LLM Architecture
# What is the Transformer architecture?
# Why did Transformers become popular for NLP?
# What are encoder and decoder architectures?
# What is an encoder-only model?
# What is a decoder-only model?
# What is an encoder-decoder model?
# Why are models like GPT decoder-only?
# What is self-attention?
# What is multi-head attention?
# What are Query, Key, and Value?
# How does attention work mathematically?
# What is scaled dot-product attention?
# Why do we divide attention scores by √dₖ?
# What is positional encoding?
# Why do Transformers need positional information?
# What is the difference between absolute and relative positional encoding?
# What is RoPE?
# What is causal attention?
# What is masked self-attention?
# What is cross-attention?
# C. LLM Training & Inference
# What is next-token prediction?
# What is a language-modeling objective?
# What is cross-entropy loss in language modeling?
# What is perplexity?
# What is teacher forcing?
# What happens during LLM inference?
# What is greedy decoding?
# What is beam search?
# What is temperature?
# What is Top-K sampling?
# What is Top-P sampling?
# How do temperature and Top-P affect output?
# What is deterministic vs stochastic generation?
# What is context length?
# What happens when the input exceeds the context window?
# What is KV caching?
# Why is KV caching useful?
# What is autoregressive generation?
# What is hallucination?
# Why do LLMs hallucinate?

# %% [markdown]
# 02 — Tokenization_Embeddings.ipynb
# A. Tokenization
# What is tokenization?
# Why don't LLMs directly process words?
# What is a token?
# What is word-level tokenization?
# What is character-level tokenization?
# What is subword tokenization?
# What is BPE?
# How does Byte Pair Encoding work?
# What is WordPiece?
# What is SentencePiece?
# What is Unigram tokenization?
# What is byte-level tokenization?
# Why is subword tokenization commonly used?
# What are special tokens?
# What are [CLS], [SEP], [PAD], [UNK], and [MASK]?
# What is a vocabulary?
# What is vocabulary size?
# How does vocabulary size affect an LLM?
# What is token ID?
# How can you count tokens in Python?
# B. Embeddings
# What is an embedding?
# Why do we convert text into embeddings?
# What is a word embedding?
# What is a sentence embedding?
# What is a document embedding?
# What is the difference between token embeddings and sentence embeddings?
# What is semantic similarity?
# What is cosine similarity?
# Why is cosine similarity commonly used for embeddings?
# What is Euclidean distance?
# What is dot-product similarity?
# What is an embedding model?
# How are embeddings generated?
# What makes a good embedding?
# What is dimensionality in an embedding?
# Why can high-dimensional embeddings be expensive?
# What is an embedding space?
# What does semantic clustering mean?
# What is an embedding index?
# What is the difference between sparse and dense representations?
# C. Vector Databases
# What is a vector database?
# Why do GenAI applications use vector databases?
# What is vector similarity search?
# What is approximate nearest-neighbor search?
# What is HNSW?
# What is FAISS?
# What is Chroma?
# What is Pinecone?
# What is Milvus?
# What is the difference between a traditional database and a vector database?
# What is metadata filtering?
# What is hybrid search?
# What is dense retrieval?
# What is sparse retrieval?
# What is reranking?
# Why is reranking useful?
# How would you choose an embedding model?
# How would you evaluate an embedding model?
# What causes poor semantic retrieval?
# How can embedding search be optimized?

# %% [markdown]
# 03 — Prompt_Engineering.ipynb
# A. Prompt Fundamentals
# What is Prompt Engineering?
# Why is prompt engineering important?
# What is a prompt?
# What are system, user, and assistant messages?
# What is zero-shot prompting?
# What is one-shot prompting?
# What is few-shot prompting?
# What is instruction prompting?
# What is role prompting?
# What is context in a prompt?
# What makes a good prompt?
# What makes a bad prompt?
# How can you make an LLM follow instructions more reliably?
# What is prompt specificity?
# What is prompt ambiguity?
# B. Advanced Prompting
# What is Chain-of-Thought prompting?
# When is Chain-of-Thought useful?
# What is Self-Consistency?
# What is Tree-of-Thought?
# What is ReAct prompting?
# What is decomposition prompting?
# What is reflection prompting?
# What is self-reflection?
# What is iterative prompting?
# What is prompt chaining?
# What is structured prompting?
# What is XML-based prompting?
# What is JSON prompting?
# How can you force structured output?
# What are output schemas?
# C. Prompt Optimization
# What is prompt template design?
# How can prompts be version-controlled?
# How can prompts be evaluated?
# What is prompt injection?
# What is indirect prompt injection?
# What is jailbreak prompting?
# How can prompt injection be prevented?
# What is instruction hierarchy?
# What is context contamination?
# How do you handle conflicting instructions?
# D. Practical Interview Questions
# How would you design a prompt for a Data Analyst AI?
# How would you design a prompt for SQL generation?
# How would you design a summarization prompt?
# How would you design a classification prompt?
# How would you design a document extraction prompt?
# How would you reduce hallucinations through prompting?
# How would you improve an inconsistent prompt?
# How would you compare two prompts?
# How would you measure prompt quality?
# How would you build a reusable prompt template?

# %% [markdown]
# 04 — RAG.ipynb
#
# This is one of the most important notebooks for GenAI interviews.
#
# A. RAG Fundamentals
# What is RAG?
# Why do we need RAG?
# What problem does RAG solve?
# How does RAG work?
# What are the major components of a RAG pipeline?
# What is a retriever?
# What is a generator?
# What is a knowledge base?
# What is document ingestion?
# What is document chunking?
# Why do we chunk documents?
# What is chunk size?
# What is chunk overlap?
# How do you choose chunk size?
# What happens if chunks are too small?
# What happens if chunks are too large?
# What is semantic chunking?
# What is recursive character splitting?
# What is metadata?
# Why is metadata important in RAG?
# B. Retrieval
# What is semantic search?
# What is vector search?
# What is keyword search?
# What is hybrid search?
# What is top-K retrieval?
# How do you select K?
# What is reranking?
# Why is reranking important?
# What is retrieval precision?
# What is retrieval recall?
# C. RAG Architecture
# Explain a complete RAG pipeline.
# What happens during document ingestion?
# What happens during query processing?
# How is the query converted into an embedding?
# How are relevant documents retrieved?
# How is retrieved context passed to an LLM?
# How does the LLM generate the final answer?
# What is contextual compression?
# What is query rewriting?
# What is multi-query retrieval?
# D. Advanced RAG
# What is Parent-Document Retrieval?
# What is Multi-Vector Retrieval?
# What is Self-RAG?
# What is Corrective RAG?
# What is Agentic RAG?
# What is Graph RAG?
# What is conversational RAG?
# What is multimodal RAG?
# How do you handle tables in RAG?
# How do you handle PDFs in RAG?
# How do you handle images in RAG?
# How do you reduce hallucination in RAG?
# How do you evaluate a RAG system?
# What are retrieval metrics?
# What are generation metrics?
# What is faithfulness?
# What is context relevance?
# What is answer relevance?
# How would you debug a poor RAG response?
# Design an end-to-end production RAG system.

# %% [markdown]
# 05 — Fine_Tuning_and_PEFT.ipynb
# A. Fine-Tuning
# What is fine-tuning?
# Why do we fine-tune an LLM?
# When should you fine-tune an LLM?
# When should you use RAG instead of fine-tuning?
# What is supervised fine-tuning?
# What is instruction tuning?
# What is domain-specific fine-tuning?
# What is task-specific fine-tuning?
# What is catastrophic forgetting?
# What is overfitting during fine-tuning?
# B. Parameter-Efficient Fine-Tuning
# What is PEFT?
# Why is PEFT useful?
# What is LoRA?
# How does LoRA work?
# Why does LoRA reduce trainable parameters?
# What are LoRA rank and alpha?
# What is a LoRA adapter?
# What is QLoRA?
# How is QLoRA different from LoRA?
# What is quantization?
# What is 4-bit quantization?
# What is 8-bit quantization?
# What is GPTQ?
# What is AWQ?
# What is bitsandbytes?
# What is adapter tuning?
# What is prefix tuning?
# What is prompt tuning?
# What is the difference between LoRA and full fine-tuning?
# What are the limitations of LoRA?
# C. Practical Fine-Tuning
# How do you prepare a dataset for fine-tuning?
# What format should instruction-tuning data use?
# How do you split a fine-tuning dataset?
# How do you choose learning rate?
# How do you choose batch size?
# What is gradient accumulation?
# What is mixed-precision training?
# What is gradient checkpointing?
# How do you monitor fine-tuning?
# How do you prevent overfitting?
# How do you evaluate a fine-tuned LLM?
# How do you compare base and fine-tuned models?
# How do you save LoRA adapters?
# How do you merge LoRA adapters?
# How would you fine-tune an LLM for a domain-specific chatbot?

# %% [markdown]
# 06 — LLM_Evaluation_and_Guardrails.ipynb
# A. LLM Evaluation
# Why is evaluating LLMs difficult?
# What is LLM evaluation?
# What is intrinsic evaluation?
# What is extrinsic evaluation?
# What is perplexity?
# What is BLEU?
# What is ROUGE?
# What is METEOR?
# What is BERTScore?
# What are the limitations of traditional NLP metrics?
# What is LLM-as-a-Judge?
# What are the advantages of LLM-as-a-Judge?
# What are the limitations of LLM-as-a-Judge?
# What is human evaluation?
# What is pairwise evaluation?
# B. RAG Evaluation
# What is retrieval evaluation?
# What is retrieval precision?
# What is retrieval recall?
# What is context relevance?
# What is context precision?
# What is faithfulness?
# What is answer relevance?
# What is groundedness?
# How do you evaluate hallucinations?
# How would you create a RAG evaluation dataset?
# C. Safety & Guardrails
# What are LLM guardrails?
# Why are guardrails necessary?
# What is input validation?
# What is output validation?
# What is content filtering?
# What is prompt injection?
# What is jailbreak?
# What is data leakage?
# What is PII protection?
# What is toxic-content filtering?
# What is hallucination detection?
# What is tool-use safety?
# What is access control for AI agents?
# What is rate limiting?
# How can you prevent an LLM from generating unsafe SQL?
# D. Production Evaluation
# How do you monitor an LLM application?
# What metrics should be monitored?
# How do you monitor latency?
# How do you monitor token usage?
# How do you monitor cost?
# How do you detect model degradation?
# What is regression testing for LLMs?
# What is an evaluation benchmark?
# How do you create an LLM test suite?
# Design an evaluation framework for a production RAG chatbot.

# %% [markdown]
# 07 — LLM_Applications.ipynb
# A. LLM Application Fundamentals
# How do you build an LLM application?
# What is an LLM API?
# What is an inference API?
# What is structured output?
# What is function calling?
# What is tool calling?
# What is JSON mode?
# What is streaming?
# Why is streaming useful?
# What is conversation history?
# B. Application Design
# How do you build a chatbot?
# How do you build a document summarizer?
# How do you build a text classification system?
# How do you build an information extraction system?
# How do you build a question-answering system?
# How do you build a SQL-generating application?
# How do you build a code-generation application?
# How do you build an email-generation application?
# How do you build a recommendation assistant?
# How do you build a data-analysis assistant?
# C. Tool & Function Calling
# What is function calling?
# Why is function calling important?
# How does an LLM decide which tool to call?
# What is a tool schema?
# How do you validate tool arguments?
# What happens after a tool is executed?
# How do you handle tool errors?
# How do you prevent unauthorized tool usage?
# What is the difference between function calling and an AI agent?
# Build a Python calculator tool for an LLM.
# D. Multimodal GenAI
# What is multimodal AI?
# What is vision-language modeling?
# How can an LLM analyze images?
# How can LLMs process PDFs?
# How can LLMs process tables?
# How can LLMs process audio?
# What is speech-to-text?
# What is text-to-speech?
# What are multimodal RAG systems?
# Design a multimodal document assistant.

# %% [markdown]
# 08 — Agentic_AI_Fundamentals.ipynb
#
# Now move from GenAI → Agentic AI.
#
# A. Agent Fundamentals
# What is an AI Agent?
# How is an AI Agent different from an LLM?
# What is Agentic AI?
# What makes a system agentic?
# What are the main components of an AI Agent?
# What is the agent loop?
# What is perception?
# What is reasoning?
# What is planning?
# What is action?
# What is observation?
# What is feedback?
# What is an environment?
# What is an agent state?
# What is an agent goal?
# B. Agent Architecture
# Explain a basic AI Agent architecture.
# What is an LLM-powered agent?
# What is a tool-using agent?
# What is a planning agent?
# What is a reactive agent?
# What is an autonomous agent?
# What is a workflow-based agent?
# What is the difference between an AI workflow and an AI agent?
# When should you use an agent?
# When should you NOT use an agent?
# C. Reasoning & Planning
# What is ReAct?
# How does ReAct work?
# What is planning in AI agents?
# What is task decomposition?
# What is hierarchical planning?
# What is reflection?
# What is self-correction?
# What is iterative reasoning?
# What is goal-directed reasoning?
# What are the limitations of autonomous reasoning?
# D. Practical
# Design a simple calculator agent.
# Design a weather-information agent.
# Design a web-search agent.
# Design a SQL agent.
# Design a Data Analyst agent.
# Design a coding agent.
# Design a research agent.
# How would you prevent an agent from entering an infinite loop?
# How would you control agent costs?
# How would you evaluate an AI agent?

# %% [markdown]
# 09 — AI_Agents_Tools_Memory.ipynb
# A. Tools
# What are tools in Agentic AI?
# Why do agents need tools?
# What types of tools can an AI Agent use?
# What is function calling?
# How does an agent select a tool?
# What is tool routing?
# What is tool validation?
# What is tool execution?
# How should tool errors be handled?
# How do you secure agent tools?
# How can an agent use Python?
# How can an agent query SQL?
# How can an agent interact with APIs?
# How can an agent search the web?
# How can an agent interact with files?
# B. Agent Memory
# What is memory in AI Agents?
# Why do agents need memory?
# What is short-term memory?
# What is long-term memory?
# What is episodic memory?
# What is semantic memory?
# What is working memory?
# What is conversation memory?
# How can an agent store memory?
# Why are vector databases useful for agent memory?
# How do you retrieve relevant memories?
# How do you prevent irrelevant memories?
# How do you update agent memory?
# How do you delete agent memories?
# What are the privacy concerns of agent memory?
# C. Agent State
# What is state in an AI Agent?
# Why is state management important?
# What information should an agent state contain?
# What is state persistence?
# What is checkpointing?
# What happens if an agent fails midway?
# How can an agent resume execution?
# How do you manage conversation state?
# How do you manage task state?
# How do you debug agent state?
# D. Practical Agent
# Build an agent that can execute Python code.
# Build an agent that can query a SQL database.
# Build an agent that can analyze CSV files.
# Build an agent with short-term memory.
# Build an agent with long-term vector memory.
# Build a Data Analyst Agent.
# How would you prevent dangerous code execution?
# How would you restrict an agent's permissions?
# How would you monitor tool calls?
# Design a production-ready tool-using agent.

# %% [markdown]
# 10 — Multi_Agent_Systems.ipynb
#
# This should be your most advanced notebook.
#
# A. Multi-Agent Fundamentals
# What is a Multi-Agent System?
# Why use multiple agents?
# How is a multi-agent system different from a single agent?
# What are the advantages of multi-agent systems?
# What are the disadvantages?
# What is agent specialization?
# What is agent collaboration?
# What is agent communication?
# What is task delegation?
# What is agent orchestration?
# B. Multi-Agent Architecture
# What is a supervisor agent?
# What is a coordinator agent?
# What is a worker agent?
# What is a planner agent?
# What is a researcher agent?
# What is a reviewer agent?
# What is a critic agent?
# What is a router agent?
# What is a hierarchical multi-agent architecture?
# What is a peer-to-peer agent architecture?
# C. Agent Communication
# How do agents communicate?
# What information should agents share?
# What is shared state?
# What is message passing?
# What is agent handoff?
# What is agent routing?
# How do you prevent communication loops?
# How do you handle conflicting agent outputs?
# How do you determine which agent is correct?
# How do you manage agent failures?
# D. Advanced Multi-Agent Systems
# What is agent delegation?
# What is dynamic task allocation?
# What is hierarchical task decomposition?
# What is collaborative planning?
# What is debate between agents?
# What is critic-reviewer architecture?
# What is planner-executor architecture?
# What is researcher-writer architecture?
# What is supervisor-worker architecture?
# What is human-in-the-loop agent architecture?
# E. Practical Projects
# Design a multi-agent research system.
# Design a Data Analyst multi-agent system.
# Design a SQL multi-agent system.
# Design a coding multi-agent system.
# Design a customer-support multi-agent system.
# Design a financial-analysis multi-agent system.
# Design a document-processing multi-agent system.
# How would you evaluate a multi-agent system?
# How would you control cost and latency?
# How would you make a multi-agent system production-ready?
