# %% [markdown]
# ## Basic Probability (1–20)

# %% [markdown]
# #### 1. What is probability?
# #### 1. What are the axioms of probability?
# #### 1. What is a random experiment?
# #### 1. What is a sample space?
# #### 1. What is an event?
# #### 1. What is the difference between a simple event and a compound event?
# #### 1. What is the difference between mutually exclusive and mutually exhaustive events?
# #### 1. What is the complement of an event?
# #### 1. What is the addition rule of probability?
# #### 1. What is the multiplication rule of probability?
# #### 1. What is an equally likely event?
# #### 1. What is experimental probability?
# #### 1. What is theoretical probability?
# #### 1. What is the difference between probability and odds?
# #### 1. What is the probability of rolling a fair die and getting an even number?
# #### 1. What is the probability of drawing an Ace from a standard deck of cards?
# #### 1. What is the probability of getting exactly one head in two coin tosses?
# #### 1. What is the difference between finite and infinite sample spaces?
# #### 1. What are impossible and certain events?
# #### 1. What is the law of total probability?

# %% [markdown]
# ## Conditional Probability (21–40)

# %% [markdown]
# #### 21. What is conditional probability?
# #### 21. When do we use conditional probability?
# #### 21. What is the formula for conditional probability?
# #### 21. What are dependent events?
# #### 21. What are independent events?
# #### 21. How can you determine whether two events are independent?
# #### 21. What is the multiplication rule for dependent events?
# #### 21. What is the multiplication rule for independent events?
# #### 21. Give a real-world example of conditional probability.
# #### 21. What is a contingency table?
# #### 21. How do you calculate probabilities from a contingency table?
# #### 21. What is the difference between joint probability and conditional probability?
# #### 21. What is marginal probability?
# #### 21. What is intersection probability?
# #### 21. What is union probability?
# #### 21. What is the inclusion-exclusion principle?
# #### 21. What is pairwise independence?
# #### 21. Can events be independent but not mutually exclusive?
# #### 21. Can mutually exclusive events be independent?
# #### 21. How is conditional probability used in machine learning?

# %% [markdown]
# ## Bayes' Theorem (41–50)

# %% [markdown]
# #### 41. What is Bayes' theorem?
# #### 41. Why is Bayes' theorem important?
# #### 41. Derive Bayes' theorem.
# #### 41. Explain prior probability.
# #### 41. Explain posterior probability.
# #### 41. Explain likelihood.
# #### 41. Explain evidence.
# #### 41. Give a real-life example of Bayes' theorem.
# #### 41. How is Bayes' theorem used in spam filtering?
# #### 41. How is Bayes' theorem used in medical diagnosis?

# %% [markdown]
# ## Random Variables (51–65)

# %% [markdown]
# #### 51. What is a random variable?
# #### 51. What is the difference between discrete and continuous random variables?
# #### 51. What is a probability mass function (PMF)?
# #### 51. What is a probability density function (PDF)?
# #### 51. What is a cumulative distribution function (CDF)?
# #### 51. What is expectation (expected value)?
# #### 51. How do you calculate expected value?
# #### 51. What is variance?
# #### 51. What is standard deviation?
# #### 51. What is covariance?
# #### 51. What is correlation?
# #### 51. Difference between covariance and correlation?
# #### 51. What is the moment generating function?
# #### 51. What is skewness?
# #### 51. What is kurtosis?

# %% [markdown]
# ## Probability Distributions (66–85)

# %% [markdown]
# #### 66. What is a probability distribution?
# #### 66. What is the Bernoulli distribution?
# #### 66. What is the Binomial distribution?
# #### 66. What assumptions does the Binomial distribution make?
# #### 66. What is the Geometric distribution?
# #### 66. What is the Negative Binomial distribution?
# #### 66. What is the Hypergeometric distribution?
# #### 66. What is the Poisson distribution?
# #### 66. When should you use the Poisson distribution?
# #### 66. What is the Uniform distribution?
# #### 66. What is the Normal distribution?
# #### 66. Why is the Normal distribution important?
# #### 66. What are the properties of the Normal distribution?
# #### 66. What is the Standard Normal distribution?
# #### 66. What is the Exponential distribution?
# #### 66. What is the Gamma distribution?
# #### 66. What is the Beta distribution?
# #### 66. What is the Chi-Square distribution?
# #### 66. What is Student's t-distribution?
# #### 66. What is the F-distribution?

# %% [markdown]
# ## Advanced Probability (86–100)

# %% [markdown]
# #### 86. What is the Central Limit Theorem?
# #### 86. Why is the Central Limit Theorem important?
# #### 86. What is the Law of Large Numbers?
# #### 86. What is convergence in probability?
# #### 86. What is convergence in distribution?
# #### 86. What are independent and identically distributed (i.i.d.) random variables?
# #### 86. What is a stochastic process?
# #### 86. What is a Markov process?
# #### 86. What is a Markov chain?
# #### 86. What is a Monte Carlo simulation?
# #### 86. What is rejection sampling?
# #### 86. What is importance sampling?
# #### 86. What is entropy in probability and information theory?
# #### 86. What is conditional independence?
# #### 86. How is probability applied in machine learning models such as Naive Bayes, Hidden Markov Models, and Bayesian Networks?

# %% [markdown]
# ## Bonus: Coding & Practical Probability Questions

# %% [markdown]
# #### 101. Simulate 10,000 coin tosses and estimate the probability of heads.
# #### 101. Simulate rolling two dice and calculate the probability of obtaining a sum of 7.
# #### 101. Verify the Law of Large Numbers through simulation.
# #### 101. Simulate the Binomial distribution using NumPy.
# #### 101. Generate samples from a Normal distribution and plot a histogram.
# #### 101. Estimate π using a Monte Carlo simulation.
# #### 101. Simulate customer arrivals using a Poisson distribution.
# #### 101. Implement Bayes' theorem for a medical testing scenario.
# #### 101. Compare theoretical and experimental probabilities for drawing cards from a deck.
# #### 101. Simulate the Central Limit Theorem by repeatedly sampling from a non-normal distribution.
