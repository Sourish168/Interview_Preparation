# %% [markdown]
# 🔹 Basic Probability (1–20)
# What is probability?
# What are the axioms of probability?
# What is a random experiment?
# What is a sample space?
# What is an event?
# What is the difference between a simple event and a compound event?
# What is the difference between mutually exclusive and mutually exhaustive events?
# What is the complement of an event?
# What is the addition rule of probability?
# What is the multiplication rule of probability?
# What is an equally likely event?
# What is experimental probability?
# What is theoretical probability?
# What is the difference between probability and odds?
# What is the probability of rolling a fair die and getting an even number?
# What is the probability of drawing an Ace from a standard deck of cards?
# What is the probability of getting exactly one head in two coin tosses?
# What is the difference between finite and infinite sample spaces?
# What are impossible and certain events?
# What is the law of total probability?
#
# 🔹 Conditional Probability (21–40)
# What is conditional probability?
# When do we use conditional probability?
# What is the formula for conditional probability?
# What are dependent events?
# What are independent events?
# How can you determine whether two events are independent?
# What is the multiplication rule for dependent events?
# What is the multiplication rule for independent events?
# Give a real-world example of conditional probability.
# What is a contingency table?
# How do you calculate probabilities from a contingency table?
# What is the difference between joint probability and conditional probability?
# What is marginal probability?
# What is intersection probability?
# What is union probability?
# What is the inclusion-exclusion principle?
# What is pairwise independence?
# Can events be independent but not mutually exclusive?
# Can mutually exclusive events be independent?
# How is conditional probability used in machine learning?
#
# 🔹 Bayes' Theorem (41–50)
# What is Bayes' theorem?
# Why is Bayes' theorem important?
# Derive Bayes' theorem.
# Explain prior probability.
# Explain posterior probability.
# Explain likelihood.
# Explain evidence.
# Give a real-life example of Bayes' theorem.
# How is Bayes' theorem used in spam filtering?
# How is Bayes' theorem used in medical diagnosis?
#
# 🔹 Random Variables (51–65)
# What is a random variable?
# What is the difference between discrete and continuous random variables?
# What is a probability mass function (PMF)?
# What is a probability density function (PDF)?
# What is a cumulative distribution function (CDF)?
# What is expectation (expected value)?
# How do you calculate expected value?
# What is variance?
# What is standard deviation?
# What is covariance?
# What is correlation?
# Difference between covariance and correlation?
# What is the moment generating function?
# What is skewness?
# What is kurtosis?
#
# 🔹 Probability Distributions (66–85)
# What is a probability distribution?
# What is the Bernoulli distribution?
# What is the Binomial distribution?
# What assumptions does the Binomial distribution make?
# What is the Geometric distribution?
# What is the Negative Binomial distribution?
# What is the Hypergeometric distribution?
# What is the Poisson distribution?
# When should you use the Poisson distribution?
# What is the Uniform distribution?
# What is the Normal distribution?
# Why is the Normal distribution important?
# What are the properties of the Normal distribution?
# What is the Standard Normal distribution?
# What is the Exponential distribution?
# What is the Gamma distribution?
# What is the Beta distribution?
# What is the Chi-Square distribution?
# What is Student's t-distribution?
# What is the F-distribution?
#
# 🔹 Advanced Probability (86–100)
# What is the Central Limit Theorem?
# Why is the Central Limit Theorem important?
# What is the Law of Large Numbers?
# What is convergence in probability?
# What is convergence in distribution?
# What are independent and identically distributed (i.i.d.) random variables?
# What is a stochastic process?
# What is a Markov process?
# What is a Markov chain?
# What is a Monte Carlo simulation?
# What is rejection sampling?
# What is importance sampling?
# What is entropy in probability and information theory?
# What is conditional independence?
# How is probability applied in machine learning models such as Naive Bayes, Hidden Markov Models, and Bayesian Networks?
#
# ⭐ Bonus: Coding & Practical Probability Questions
# Simulate 10,000 coin tosses and estimate the probability of heads.
# Simulate rolling two dice and calculate the probability of obtaining a sum of 7.
# Verify the Law of Large Numbers through simulation.
# Simulate the Binomial distribution using NumPy.
# Generate samples from a Normal distribution and plot a histogram.
# Estimate π using a Monte Carlo simulation.
# Simulate customer arrivals using a Poisson distribution.
# Implement Bayes' theorem for a medical testing scenario.
# Compare theoretical and experimental probabilities for drawing cards from a deck.
# Simulate the Central Limit Theorem by repeatedly sampling from a non-normal distribution.
