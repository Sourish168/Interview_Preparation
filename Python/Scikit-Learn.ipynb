# %% [markdown]
# ## Basic Level (1–20)

# %% [markdown]
# #### 1. What is Scikit-Learn?
# #### 1. Why is Scikit-Learn widely used?
# #### 1. What are the main modules in Scikit-Learn?
# #### 1. What types of machine learning algorithms does Scikit-Learn support?
# #### 1. What is an estimator in Scikit-Learn?
# #### 1. What is the difference between fit() and transform()?
# #### 1. What does fit_transform() do?
# #### 1. What is predict()?
# #### 1. What is the difference between supervised and unsupervised learning?
# #### 1. Which algorithms are available for classification?
# #### 1. Which algorithms are available for regression?
# #### 1. Which algorithms are available for clustering?
# #### 1. What is feature engineering?
# #### 1. Why is feature scaling important?
# #### 1. What is train-test split?
# #### 1. How do you split a dataset into training and testing sets?
# #### 1. What is random state?
# #### 1. What is model evaluation?
# #### 1. What are features (X) and target (y)?
# #### 1. What is overfitting?

# %% [markdown]
# ## Data Preprocessing (21–40)

# %% [markdown]
# #### 21. Why is preprocessing necessary?
# #### 21. What is StandardScaler?
# #### 21. What is MinMaxScaler?
# #### 21. Difference between StandardScaler and MinMaxScaler?
# #### 21. What is RobustScaler?
# #### 21. What is normalization?
# #### 21. Difference between normalization and standardization?
# #### 21. What is one-hot encoding?
# #### 21. What is label encoding?
# #### 21. Difference between one-hot encoding and label encoding?
# #### 21. What is ColumnTransformer?
# #### 21. What is Pipeline?
# #### 21. Why use pipelines?
# #### 21. How do you handle missing values?
# #### 21. What is SimpleImputer?
# #### 21. What is KNNImputer?
# #### 21. What is feature selection?
# #### 21. What is SelectKBest?
# #### 21. What is PCA?
# #### 21. Why perform dimensionality reduction?

# %% [markdown]
# ## Classification (41–60)

# %% [markdown]
# #### 41. What is logistic regression?
# #### 41. Why is logistic regression called regression?
# #### 41. What is K-Nearest Neighbors?
# #### 41. What is Decision Tree?
# #### 41. What is Random Forest?
# #### 41. What is Support Vector Machine?
# #### 41. What is Naive Bayes?
# #### 41. What is Gradient Boosting?
# #### 41. What is AdaBoost?
# #### 41. What is XGBoost, and is it part of Scikit-Learn?
# #### 41. What is the confusion matrix?
# #### 41. What is accuracy?
# #### 41. What is precision?
# #### 41. What is recall?
# #### 41. What is the F1-score?
# #### 41. What is ROC-AUC?
# #### 41. What is a classification report?
# #### 41. When is accuracy a poor metric?
# #### 41. What is class imbalance?
# #### 41. How do you handle imbalanced datasets?

# %% [markdown]
# ## Regression (61–75)

# %% [markdown]
# #### 61. What is linear regression?
# #### 61. What is multiple linear regression?
# #### 61. What is polynomial regression?
# #### 61. What is Ridge regression?
# #### 61. What is Lasso regression?
# #### 61. Difference between Ridge and Lasso?
# #### 61. What is Elastic Net?
# #### 61. What is Mean Absolute Error (MAE)?
# #### 61. What is Mean Squared Error (MSE)?
# #### 61. What is Root Mean Squared Error (RMSE)?
# #### 61. What is R² score?
# #### 61. What is adjusted R²?
# #### 61. When would you choose MAE over RMSE?
# #### 61. What assumptions does linear regression make?
# #### 61. How do you detect multicollinearity?

# %% [markdown]
# ## Model Selection & Validation (76–90)

# %% [markdown]
# #### 76. What is cross-validation?
# #### 76. Why is cross-validation better than a single train-test split?
# #### 76. What is K-Fold Cross Validation?
# #### 76. What is Stratified K-Fold?
# #### 76. What is Leave-One-Out Cross Validation?
# #### 76. What is Grid Search?
# #### 76. What is Randomized Search?
# #### 76. Difference between Grid Search and Randomized Search?
# #### 76. What is hyperparameter tuning?
# #### 76. What are hyperparameters?
# #### 76. What is bias-variance tradeoff?
# #### 76. How do you reduce overfitting?
# #### 76. How do you reduce underfitting?
# #### 76. What is learning curve analysis?
# #### 76. What is validation curve analysis?

# %% [markdown]
# ## Advanced Level (91–100)

# %% [markdown]
# #### 91. What is the Scikit-Learn estimator API?
# #### 91. What is the difference between fit(), partial_fit(), and warm_start?
# #### 91. How does Scikit-Learn handle sparse matrices?
# #### 91. What is FeatureUnion?
# #### 91. How do pipelines help prevent data leakage?
# #### 91. What is permutation feature importance?
# #### 91. What is recursive feature elimination (RFE)?
# #### 91. How do you save and load trained Scikit-Learn models?
# #### 91. What are the limitations of Scikit-Learn compared with deep learning frameworks like TensorFlow or PyTorch?
# #### 91. How would you build an end-to-end machine learning pipeline in Scikit-Learn?

# %% [markdown]
# ## Hands-on Coding Questions

# %% [markdown]
# #### 101. Load a dataset and split it into training and testing sets.
# #### 101. Build a linear regression model.
# #### 101. Train a logistic regression classifier.
# #### 101. Perform one-hot encoding for categorical variables.
# #### 101. Scale numerical features using StandardScaler.
# #### 101. Build a complete preprocessing and modeling Pipeline.
# #### 101. Use ColumnTransformer to preprocess mixed data types.
# #### 101. Perform hyperparameter tuning using GridSearchCV.
# #### 101. Evaluate a classification model using a confusion matrix and ROC-AUC.
# #### 101. Save the trained model using joblib or pickle and load it for inference.
