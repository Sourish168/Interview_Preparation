# %% [markdown]
# ## Basic Level (1–20)

# %% [markdown]
# What is Scikit-Learn?
# Why is Scikit-Learn widely used?
# What are the main modules in Scikit-Learn?
# What types of machine learning algorithms does Scikit-Learn support?
# What is an estimator in Scikit-Learn?
# What is the difference between fit() and transform()?
# What does fit_transform() do?
# What is predict()?
# What is the difference between supervised and unsupervised learning?
# Which algorithms are available for classification?
# Which algorithms are available for regression?
# Which algorithms are available for clustering?
# What is feature engineering?
# Why is feature scaling important?
# What is train-test split?
# How do you split a dataset into training and testing sets?
# What is random state?
# What is model evaluation?
# What are features (X) and target (y)?
# What is overfitting?

# %% [markdown]
# ## Data Preprocessing (21–40)

# %% [markdown]
# Why is preprocessing necessary?
# What is StandardScaler?
# What is MinMaxScaler?
# Difference between StandardScaler and MinMaxScaler?
# What is RobustScaler?
# What is normalization?
# Difference between normalization and standardization?
# What is one-hot encoding?
# What is label encoding?
# Difference between one-hot encoding and label encoding?
# What is ColumnTransformer?
# What is Pipeline?
# Why use pipelines?
# How do you handle missing values?
# What is SimpleImputer?
# What is KNNImputer?
# What is feature selection?
# What is SelectKBest?
# What is PCA?
# Why perform dimensionality reduction?

# %% [markdown]
# ## Classification (41–60)

# %% [markdown]
# What is logistic regression?
# Why is logistic regression called regression?
# What is K-Nearest Neighbors?
# What is Decision Tree?
# What is Random Forest?
# What is Support Vector Machine?
# What is Naive Bayes?
# What is Gradient Boosting?
# What is AdaBoost?
# What is XGBoost, and is it part of Scikit-Learn?
# What is the confusion matrix?
# What is accuracy?
# What is precision?
# What is recall?
# What is the F1-score?
# What is ROC-AUC?
# What is a classification report?
# When is accuracy a poor metric?
# What is class imbalance?
# How do you handle imbalanced datasets?

# %% [markdown]
# ## Regression (61–75)

# %% [markdown]
# What is linear regression?
# What is multiple linear regression?
# What is polynomial regression?
# What is Ridge regression?
# What is Lasso regression?
# Difference between Ridge and Lasso?
# What is Elastic Net?
# What is Mean Absolute Error (MAE)?
# What is Mean Squared Error (MSE)?
# What is Root Mean Squared Error (RMSE)?
# What is R² score?
# What is adjusted R²?
# When would you choose MAE over RMSE?
# What assumptions does linear regression make?
# How do you detect multicollinearity?

# %% [markdown]
# ## Model Selection & Validation (76–90)

# %% [markdown]
# What is cross-validation?
# Why is cross-validation better than a single train-test split?
# What is K-Fold Cross Validation?
# What is Stratified K-Fold?
# What is Leave-One-Out Cross Validation?
# What is Grid Search?
# What is Randomized Search?
# Difference between Grid Search and Randomized Search?
# What is hyperparameter tuning?
# What are hyperparameters?
# What is bias-variance tradeoff?
# How do you reduce overfitting?
# How do you reduce underfitting?
# What is learning curve analysis?
# What is validation curve analysis?

# %% [markdown]
# ## Advanced Level (91–100)

# %% [markdown]
# What is the Scikit-Learn estimator API?
# What is the difference between fit(), partial_fit(), and warm_start?
# How does Scikit-Learn handle sparse matrices?
# What is FeatureUnion?
# How do pipelines help prevent data leakage?
# What is permutation feature importance?
# What is recursive feature elimination (RFE)?
# How do you save and load trained Scikit-Learn models?
# What are the limitations of Scikit-Learn compared with deep learning frameworks like TensorFlow or PyTorch?
# How would you build an end-to-end machine learning pipeline in Scikit-Learn?

# %% [markdown]
# ## Hands-on Coding Questions

# %% [markdown]
# Load a dataset and split it into training and testing sets.
# Build a linear regression model.
# Train a logistic regression classifier.
# Perform one-hot encoding for categorical variables.
# Scale numerical features using StandardScaler.
# Build a complete preprocessing and modeling Pipeline.
# Use ColumnTransformer to preprocess mixed data types.
# Perform hyperparameter tuning using GridSearchCV.
# Evaluate a classification model using a confusion matrix and ROC-AUC.
# Save the trained model using joblib or pickle and load it for inference.
