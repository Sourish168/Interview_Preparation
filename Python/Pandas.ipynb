# %% [markdown]
# ## Basic Level (1–20)

# %% [markdown]
# #### **1. What is pandas?**
# #### **1. Why is Pandas used in Data Science?**
# #### **1. What are the main data structures in Pandas?**
# #### **1. What is a Series?**
# #### **1. What is a DataFrame?**
# #### **1. What is the difference between a Series and a DataFrame?**
# #### **1. How do you create a Series?**
# #### **1. How do you create a DataFrame?**
# #### **1. How do you read data from a CSV file?**
# #### **1. How do you write a DataFrame to a CSV file?**
# #### **1. How do you display the first few rows of a DataFrame?**
# #### **1. How do you display the last few rows?**
# #### **1. What does df.info() do?**
# #### **1. What does df.describe() return?**
# #### **1. How do you check the shape of a DataFrame?**
# #### **1. How do you list column names?**
# #### **1. How do you check data types of columns?**
# #### **1. How do you rename columns?**
# #### **1. How do you select a single column?**
# #### **1. How do you select multiple columns?**

# %% [markdown]
# ## Intermediate Level (21–50)

# %% [markdown]
# #### **21. What is the difference between loc[] and iloc[]?**
# #### **21. What is label-based indexing?**
# #### **21. What is integer-based indexing?**
# #### **21. How do you filter rows based on conditions?**
# #### **21. How do you select rows with multiple conditions?**
# #### **21. What is boolean indexing?**
# #### **21. How do you sort a DataFrame?**
# #### **21. What is the difference between sort_values() and sort_index()?**
# #### **21. How do you remove duplicate rows?**
# #### **21. How do you count duplicates?**
# #### **21. How do you handle missing values?**
# #### **21. Difference between dropna() and fillna()?**
# #### **21. How do you replace missing values with the mean?**
# #### **21. How do you detect missing values?**
# #### **21. Difference between isna() and notna()?**
# #### **21. How do you add a new column?**
# #### **21. How do you delete a column?**
# #### **21. Difference between drop() and del?**
# #### **21. How do you change data types?**
# #### **21. What is astype()?**
# #### **21. How do you apply a function to a column?**
# #### **21. What is apply()?**
# #### **21. Difference between apply(), map(), and applymap()?**
# #### **21. What is value_counts()?**
# #### **21. What is unique()?**
# #### **21. What is nunique()?**
# #### **21. How do you rename index values?**
# #### **21. How do you reset the index?**
# #### **21. What is set_index()?**
# #### **21. Why are indexes important?**

# %% [markdown]
# ## Data Manipulation (51–70)

# %% [markdown]
# #### **51. What is groupby()?**
# #### **51. How does groupby() work internally?**
# #### **51. Difference between aggregation and transformation?**
# #### **51. What are aggregation functions?**
# #### **51. How do you calculate multiple aggregations?**
# #### **51. What is pivot_table()?**
# #### **51. Difference between pivot() and pivot_table()?**
# #### **51. What is melting?**
# #### **51. What is melt()?**
# #### **51. What is stack()?**
# #### **51. What is unstack()?**
# #### **51. Difference between long and wide data?**
# #### **51. What is explode()?**
# #### **51. What is crosstab()?**
# #### **51. What is cut()?**
# #### **51. What is qcut()?**
# #### **51. How do you bin continuous data?**
# #### **51. What is transform()?**
# #### **51. Difference between transform() and aggregate()?**
# #### **51. What is pipe()?**

# %% [markdown]
# ## Merge, Join & Combine (71–85)

# %% [markdown]
# #### **71. Difference between merge(), join(), and concat()?**
# #### **71. Explain different types of joins.**
# #### **71. What is an inner join?**
# #### **71. What is a left join?**
# #### **71. What is a right join?**
# #### **71. What is a full outer join?**
# #### **71. What happens when merge keys have duplicates?**
# #### **71. How do you merge on multiple columns?**
# #### **71. How do you concatenate DataFrames vertically?**
# #### **71. How do you concatenate horizontally?**
# #### **71. What is hierarchical indexing?**
# #### **71. What is a MultiIndex?**
# #### **71. How do you flatten a MultiIndex?**
# #### **71. What is combine_first()?**
# #### **71. How do you compare two DataFrames?**

# %% [markdown]
# ## Advanced Level (86–100)

# %% [markdown]
# #### **86. How is a DataFrame stored in memory?**
# #### **86. Why is Pandas slower than NumPy for numerical operations?**
# #### **86. What is vectorization in Pandas?**
# #### **86. When should you avoid using apply()?**
# #### **86. How can you optimize large DataFrames?**
# #### **86. What are categorical data types, and when should you use them?**
# #### **86. How do you reduce memory usage in a DataFrame?**
# #### **86. What are time series in Pandas?**
# #### **86. How do you work with datetime columns?**
# #### **86. What is resampling?**
# #### **86. What is rolling window analysis?**
# #### **86. How do you handle time zones in Pandas?**
# #### **86. How would you process a 10 GB CSV that doesn't fit into memory?**
# #### **86. What are common performance bottlenecks in Pandas, and how can you address them?**
# #### **86. In what situations would you choose Pandas over NumPy, and when would you choose NumPy instead?**

# %% [markdown]
# ## Frequently Asked Scenario-Based Questions

# %% [markdown]
# #### **101. How would you clean a messy dataset before analysis?**
# #### **101. How do you identify and remove duplicate records?**
# #### **101. How would you fill missing values differently for numerical and categorical columns?**
# #### **101. How do you detect and handle outliers using Pandas?**
# #### **101. How would you find the top 5 customers by total sales?**
# #### **101. How would you calculate month-over-month growth from a sales dataset?**
# #### **101. How do you combine data from multiple CSV files into one DataFrame?**
# #### **101. How would you reshape a dataset from wide format to long format?**
# #### **101. How do you optimize a slow Pandas script processing millions of rows?**
# #### **101. What are the most common mistakes developers make when working with Pandas?**
