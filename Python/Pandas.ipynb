# %% [markdown]
# ## Basic Level (1–20)

# %% [markdown]
# What is pandas?
# Why is Pandas used in Data Science?
# What are the main data structures in Pandas?
# What is a Series?
# What is a DataFrame?
# What is the difference between a Series and a DataFrame?
# How do you create a Series?
# How do you create a DataFrame?
# How do you read data from a CSV file?
# How do you write a DataFrame to a CSV file?
# How do you display the first few rows of a DataFrame?
# How do you display the last few rows?
# What does df.info() do?
# What does df.describe() return?
# How do you check the shape of a DataFrame?
# How do you list column names?
# How do you check data types of columns?
# How do you rename columns?
# How do you select a single column?
# How do you select multiple columns?

# %% [markdown]
# ## Intermediate Level (21–50)

# %% [markdown]
# What is the difference between loc[] and iloc[]?
# What is label-based indexing?
# What is integer-based indexing?
# How do you filter rows based on conditions?
# How do you select rows with multiple conditions?
# What is boolean indexing?
# How do you sort a DataFrame?
# What is the difference between sort_values() and sort_index()?
# How do you remove duplicate rows?
# How do you count duplicates?
# How do you handle missing values?
# Difference between dropna() and fillna()?
# How do you replace missing values with the mean?
# How do you detect missing values?
# Difference between isna() and notna()?
# How do you add a new column?
# How do you delete a column?
# Difference between drop() and del?
# How do you change data types?
# What is astype()?
# How do you apply a function to a column?
# What is apply()?
# Difference between apply(), map(), and applymap()?
# What is value_counts()?
# What is unique()?
# What is nunique()?
# How do you rename index values?
# How do you reset the index?
# What is set_index()?
# Why are indexes important?

# %% [markdown]
# ## Data Manipulation (51–70)

# %% [markdown]
# What is groupby()?
# How does groupby() work internally?
# Difference between aggregation and transformation?
# What are aggregation functions?
# How do you calculate multiple aggregations?
# What is pivot_table()?
# Difference between pivot() and pivot_table()?
# What is melting?
# What is melt()?
# What is stack()?
# What is unstack()?
# Difference between long and wide data?
# What is explode()?
# What is crosstab()?
# What is cut()?
# What is qcut()?
# How do you bin continuous data?
# What is transform()?
# Difference between transform() and aggregate()?
# What is pipe()?

# %% [markdown]
# ## Merge, Join & Combine (71–85)

# %% [markdown]
# Difference between merge(), join(), and concat()?
# Explain different types of joins.
# What is an inner join?
# What is a left join?
# What is a right join?
# What is a full outer join?
# What happens when merge keys have duplicates?
# How do you merge on multiple columns?
# How do you concatenate DataFrames vertically?
# How do you concatenate horizontally?
# What is hierarchical indexing?
# What is a MultiIndex?
# How do you flatten a MultiIndex?
# What is combine_first()?
# How do you compare two DataFrames?

# %% [markdown]
# ## Advanced Level (86–100)

# %% [markdown]
# How is a DataFrame stored in memory?
# Why is Pandas slower than NumPy for numerical operations?
# What is vectorization in Pandas?
# When should you avoid using apply()?
# How can you optimize large DataFrames?
# What are categorical data types, and when should you use them?
# How do you reduce memory usage in a DataFrame?
# What are time series in Pandas?
# How do you work with datetime columns?
# What is resampling?
# What is rolling window analysis?
# How do you handle time zones in Pandas?
# How would you process a 10 GB CSV that doesn't fit into memory?
# What are common performance bottlenecks in Pandas, and how can you address them?
# In what situations would you choose Pandas over NumPy, and when would you choose NumPy instead?

# %% [markdown]
# ## Frequently Asked Scenario-Based Questions

# %% [markdown]
# How would you clean a messy dataset before analysis?
# How do you identify and remove duplicate records?
# How would you fill missing values differently for numerical and categorical columns?
# How do you detect and handle outliers using Pandas?
# How would you find the top 5 customers by total sales?
# How would you calculate month-over-month growth from a sales dataset?
# How do you combine data from multiple CSV files into one DataFrame?
# How would you reshape a dataset from wide format to long format?
# How do you optimize a slow Pandas script processing millions of rows?
# What are the most common mistakes developers make when working with Pandas?
